# %% [markdown]
# ##**Mastering the Pinecone vector database.**

# %% [markdown]
# ##**GOAL: save text sentence embeddings and perform semantic search in Pinecone using Python code.**

# %% [markdown]
# Create a Pinecone Account: Head to 'Pinecone.io' and sign up for a free account. After signing up, you’ll be given an API key.

# %% [markdown]
#  To start working with Pinecone,
# install 'pinecone' library

# %%
# place your code here
# !pip install pinecone

# %% [markdown]
# From 'pinecone' library import Pinecone, ServerlessSpec.

# %%
# place your code here
from pinecone import Pinecone, ServerlessSpec

# %% [markdown]
# On the Pinecone main page, navigate to the "Get started" section via the left menu. Next, follow the "Quick Start for Developers" guide.
# * Initialaze a client.
# * Create an index.
# * Upsert data.
# * Perform a search.

# %% [markdown]
# When you perform "Upsert data", add a list of your own text strings.

# %% [markdown]
# When you perform "Search", use of your own text string.

# %%
# place your code here
pc = Pinecone(api_key="pcsk_oqq5v_JsMNBGygcPN1ZNN7VHN1ofFSH9v8AaF1YYXc7tBR3cxjN4aHHGJCvLxyn3mUwEm")
index_name = "test"
if not pc.has_index(index_name):
    pc.create_index_for_model(
        name=index_name,
        cloud="aws",
        region="us-east-1",
        embed={
            "model":"llama-text-embed-v2",
            "field_map":{"text": "chunk_text"}
        }
    )

index = pc.Index(index_name)


texts = [
    "I love programming Python",
    "Machine learning is cool",
    "Math and Programming skills are important in computer science",
    "I like solving algorithmic problems"
]

response = openai.Embedding.create(
    model="text-embedding-3-small",
    input=texts
)
vectors = []
for i, emb in enumerate(response["data"]):
    vectors.append({
        "id": f"vec-{i}",
        "values": emb["values"],
        "metadata": {"text": texts[i]}
    })

index.upsert(vectors=vectors)
# Out:
# ---------------------------------------------------------------------------
# NotFoundException                         Traceback (most recent call last)
# Cell In[10], line 25
#      15 index = pc.Index(index_name)
#      18 texts = [
#      19     "I love programming Python",
#      20     "Machine learning is cool",
#      21     "Math and Programming skills are important in computer science",
#      22     "I like solving algorithmic problems"
#      23 ]
# ---> 25 embeddings = pc.inference.embed(
#      26     model="multilingual-e5-small",
#      27     inputs=texts
#      28 )
#      29 vectors = []
#      30 for i, emb in enumerate(embeddings):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\inference\inference.py:226, in Inference.embed(self, model, inputs, parameters)
#     161 """
#     162 Generates embeddings for the provided inputs using the specified model and (optional) parameters.
#     163
#    (...)    221
#     222 """
#     223 request_body = InferenceRequestBuilder.embed_request(
#     224     model=model, inputs=inputs, parameters=parameters
#     225 )
# --> 226 resp = self.__inference_api.embed(embed_request=request_body)
#     227 return EmbeddingsList(resp)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\core\openapi\inference\api\inference_api.py:93, in InferenceApi.__init__.<locals>.__embed(self, x_pinecone_api_version, **kwargs)
#      90 kwargs = self._process_openapi_kwargs(kwargs)
#      91 kwargs["x_pinecone_api_version"] = x_pinecone_api_version
#      92 return cast(
# ---> 93     EmbeddingsList | ApplyResult[EmbeddingsList], self.call_with_http_info(**kwargs)
#      94 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:320, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     299     return self.threadpool_executor.submit(
#     300         self.__call_api,
#     301         resource_path,
#    (...)    316         _check_type,
#     317     )
#     319 if not async_req:
# --> 320     return self.__call_api(
#     321         resource_path,
#     322         method,
#     323         path_params,
#     324         query_params,
#     325         header_params,
#     326         body,
#     327         post_params,
#     328         files,
#     329         response_type,
#     330         auth_settings,
#     331         _return_http_data_only,
#     332         collection_formats,
#     333         _preload_content,
#     334         _request_timeout,
#     335         _host,
#     336         _check_type,
#     337     )
#     339 return self.pool.apply_async(
#     340     self.__call_api,
#     341     (
#    (...)    358     ),
#     359 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:185, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
# --> 185     raise e
#     187 self.last_response = response_data
#     189 return_data = response_data
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:173, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     164 url = build_request_url(
#     165     config=config,
#     166     processed_path_params=path_params_tuple,
#     167     resource_path=resource_path,
#     168     _host=_host,
#     169 )
#     171 try:
#     172     # perform request and return response
# --> 173     response_data = self.request(
#     174         method,
#     175         url,
#     176         query_params=processed_query_params,
#     177         headers=headers_tuple,
#     178         post_params=processed_post_params,
#     179         body=body,
#     180         _preload_content=_preload_content,
#     181         _request_timeout=_request_timeout,
#     182     )
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:400, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     390     return self.rest_client.OPTIONS(
#     391         url,
#     392         query_params=query_params,
#    (...)    397         body=body,
#     398     )
#     399 elif method == "POST":
# --> 400     return self.rest_client.POST(
#     401         url,
#     402         query_params=query_params,
#     403         headers=headers,
#     404         post_params=post_params,
#     405         _preload_content=_preload_content,
#     406         _request_timeout=_request_timeout,
#     407         body=body,
#     408     )
#     409 elif method == "PUT":
#     410     return self.rest_client.PUT(
#     411         url,
#     412         query_params=query_params,
#    (...)    417         body=body,
#     418     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\rest_urllib3.py:270, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     267     # log response body
#     268     logger.debug("response body: %s", r.data)
# --> 270 return raise_exceptions_or_return(r)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\rest_utils.py:44, in raise_exceptions_or_return(r)
#      41     raise ForbiddenException(http_resp=r)
#      43 if r.status == 404:
# ---> 44     raise NotFoundException(http_resp=r)
#      46 if 500 <= r.status <= 599:
#      47     raise ServiceException(http_resp=r)
#
# NotFoundException: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'x-pinecone-api-version': '2025-10', 'access-control-allow-origin': '*', 'vary': 'origin, access-control-request-method, access-control-request-headers', 'access-control-expose-headers': '*', 'x-cloud-trace-context': 'e8d55110ced9365ae2d894a57eb5eb5a', 'date': 'Thu, 19 Feb 2026 11:24:55 GMT', 'server': 'Google Frontend', 'Content-Length': '95', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"NOT_FOUND","message":"Model 'multilingual-e5-small' not found"},"status":404}

# %% [markdown]
# Print search results.

# %%
# place your code here
